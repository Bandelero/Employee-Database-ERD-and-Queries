# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@Localhost/sql-challenge')
conn = engine.connect()

# %%
df_salaries = pd.read_sql("select * from salaries", conn)
df_salaries.hist(column='salary')
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>]], dtype=object)

# %%
df_avgsalaries = pd.read_sql("select round(avg(salary),2) as Average, titles.title from salaries join titles on titles.emp_no=salaries.emp_no group by titles.title;", conn)
df_avgsalaries.head()
# Out:
#     average               title
# 0  48493.20  Assistant Engineer
# 1  48539.78            Engineer
# 2  51531.04             Manager
# 3  48506.75     Senior Engineer
# 4  58503.29        Senior Staff

# %%
plt.bar(df_avgsalaries.title, df_avgsalaries.average, color='r')
plt.xticks(rotation=45)
plt.title("Average Salaries")
plt.xlabel("Titles")
plt.ylabel("Salaries")
# Out:
# Text(0, 0.5, 'Salaries')
